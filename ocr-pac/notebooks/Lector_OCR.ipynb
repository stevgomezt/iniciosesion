# %% [markdown]
# # Libreria

# %%
from shutil import rmtree # libreria para remover la carpeta con archivos

import pandas as pd
from functions import func_check, func_OCR, convert_from_path

# %% [markdown]
# # ubicación de archivos

# %%
# @title Cargar todos los PDFs solicitados
# @markdown creación de archivos organizados
# !mkdir input_papers
# !mkdir input_papers_zip
# !mkdir output_papers
# !mkdir output_papers_
# !mkdir output_papers_prueba
# !mkdir output_papers_prueba1

# @markdown Carpetas para gestión de archivos
input_folder_path = 'input_papers/'
output_folder_path = "output_papers/"
output_folder_path_= "output_papers_/"
output_folder_path_prueba1= "output_papers_prueba1/"

# Carga
license_keys = r'C:\Users\dflunan\Documents\dokcer ocr\ReportePDA_AnaConstanzaJaramilloPosada.pdf'
# Out:
# Ya existe el subdirectorio o el archivo input_papers.
# Ya existe el subdirectorio o el archivo output_papers.
# Ya existe el subdirectorio o el archivo output_papers_.
# Ya existe el subdirectorio o el archivo output_papers_prueba1.

# %%
# @title  Realizar la lectura y tabulación de la información
Perfil_final = func_OCR(output_folder_path, output_folder_path_prueba1, output_folder_path_)
Perfil_final
# Out:
# Converting : ReportePDA_AnaConstanzaJaramilloPosada.pdf
# input_papers/ReportePDA_AnaConstanzaJaramilloPosada.pdf
# Lectura del archivo: input_papers\ReportePDA_AnaConstanzaJaramilloPosada.pdf
# ReportePDA_AnaConstanzaJaramilloPosada.pdf
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\dflunan\AppData\Local\anaconda3\envs\ocr\Lib\site-packages\pdf2image\pdf2image.py:581, in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout, first_page, last_page)
#     580     env["LD_LIBRARY_PATH"] = poppler_path + ":" + env.get("LD_LIBRARY_PATH", "")
# --> 581 proc = Popen(command, env=env, stdout=PIPE, stderr=PIPE)
#     583 try:
#
# File c:\Users\dflunan\AppData\Local\anaconda3\envs\ocr\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#
# File c:\Users\dflunan\AppData\Local\anaconda3\envs\ocr\Lib\subprocess.py:1538, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1537 try:
# -> 1538     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1539                              # no special security
#    1540                              None, None,
#    1541                              int(not close_fds),
#    1542                              creationflags,
#    1543                              env,
#    1544                              cwd,
#    1545                              startupinfo)
#    1546 finally:
#    1547     # Child is launched. Close the parent's copy of those pipe
#    1548     # handles that only the child should have open.  You need
#    (...)
#    1551     # pipe will not close when the child process exits and the
#    1552     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] El sistema no puede encontrar el archivo especificado
#
# During handling of the above exception, another exception occurred:
#
# PDFInfoNotInstalledError                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 # @title  Realizar la lectura y tabulación de la información
# ----> 2 Perfil_final = func_OCR(input_folder_path)
#       3 Perfil_final
#
# File c:\Users\dflunan\Documents\dokcer ocr\functions.py:165, in func_OCR(output_folder_path)
#     163   output_filename = output_folder_path+filename # Versión 2
#     164   print(output_filename)
# --> 165 Perfil, image, image2 = Extract_text_from_pdf(output_folder_path)
#     166 Perfil_final = Function_reading_data_pdf(Perfil, image, image2) # Tabulación de la información luego de la lectura.
#     167 return Perfil_final
#
# File c:\Users\dflunan\Documents\dokcer ocr\functions.py:117, in Extract_text_from_pdf(pdf_path, Save_txt)
#     115 # Lectura del perfil Normal y Adaptado
#     116 print(filename)
# --> 117 pages = convert_from_path(file)
#     118 pages_= convert_from_path(file, dpi=300)
#     119 # for i in range(len(pages)):
#     120 # Guardar página como imagen
#     121 # plt.imshow(pages[0])
#
# File c:\Users\dflunan\AppData\Local\anaconda3\envs\ocr\Lib\site-packages\pdf2image\pdf2image.py:127, in convert_from_path(pdf_path, dpi, output_folder, first_page, last_page, fmt, jpegopt, thread_count, userpw, ownerpw, use_cropbox, strict, transparent, single_file, output_file, poppler_path, grayscale, size, paths_only, use_pdftocairo, timeout, hide_annotations)
#     124 if isinstance(poppler_path, PurePath):
#     125     poppler_path = poppler_path.as_posix()
# --> 127 page_count = pdfinfo_from_path(
#     128     pdf_path, userpw, ownerpw, poppler_path=poppler_path
#     129 )["Pages"]
#     131 # We start by getting the output format, the buffer processing function and if we need pdftocairo
#     132 parsed_fmt, final_extension, parse_buffer_func, use_pdfcairo_format = _parse_format(
#     133     fmt, grayscale
#     134 )
#
# File c:\Users\dflunan\AppData\Local\anaconda3\envs\ocr\Lib\site-packages\pdf2image\pdf2image.py:607, in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout, first_page, last_page)
#     604     return d
#     606 except OSError:
# --> 607     raise PDFInfoNotInstalledError(
#     608         "Unable to get page count. Is poppler installed and in PATH?"
#     609     )
#     610 except ValueError:
#     611     raise PDFPageCountError(
#     612         f"Unable to get page count.\n{err.decode('utf8', 'ignore')}"
#     613     )
#
# PDFInfoNotInstalledError: Unable to get page count. Is poppler installed and in PATH?

# %%
# @title Eliminación de las carpetas temporales, creadas para la lectura del archivo PDA
rmtree('input_papers')
rmtree('output_papers')
rmtree('output_papers_')
rmtree('output_papers_prueba1')
